# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Анализ-признаков-без-взаимодействий,-первичная-фильтрация" data-toc-modified-id="Анализ-признаков-без-взаимодействий,-первичная-фильтрация-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Анализ признаков без взаимодействий, первичная фильтрация</a></span><ul class="toc-item"><li><span><a href="#Price" data-toc-modified-id="Price-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Price</a></span></li><li><span><a href="#Square_Total" data-toc-modified-id="Square_Total-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Square_Total</a></span></li><li><span><a href="#Square_Kitchen" data-toc-modified-id="Square_Kitchen-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Square_Kitchen</a></span></li><li><span><a href="#Square_Living" data-toc-modified-id="Square_Living-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Square_Living</a></span></li><li><span><a href="#Floors_In_Building" data-toc-modified-id="Floors_In_Building-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Floors_In_Building</a></span></li><li><span><a href="#Floor" data-toc-modified-id="Floor-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Floor</a></span></li><li><span><a href="#District" data-toc-modified-id="District-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>District</a></span></li><li><span><a href="#Year_Building" data-toc-modified-id="Year_Building-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Year_Building</a></span></li><li><span><a href="#Material" data-toc-modified-id="Material-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Material</a></span></li><li><span><a href="#Apartment_Type" data-toc-modified-id="Apartment_Type-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Apartment_Type</a></span></li><li><span><a href="#Rooms_Number" data-toc-modified-id="Rooms_Number-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Rooms_Number</a></span></li><li><span><a href="#Apartment_Condition" data-toc-modified-id="Apartment_Condition-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Apartment_Condition</a></span></li><li><span><a href="#Bathroom_Type" data-toc-modified-id="Bathroom_Type-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Bathroom_Type</a></span></li><li><span><a href="#Balcony_Loggia" data-toc-modified-id="Balcony_Loggia-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>Balcony_Loggia</a></span></li><li><span><a href="#Address,-Date_Add,-Date_Expiration" data-toc-modified-id="Address,-Date_Add,-Date_Expiration-1.15"><span class="toc-item-num">1.15&nbsp;&nbsp;</span>Address, Date_Add, Date_Expiration</a></span></li></ul></li><li><span><a href="#Анализ-признаков-с-взаимодействиями,-фильтрация-данных" data-toc-modified-id="Анализ-признаков-с-взаимодействиями,-фильтрация-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ признаков с взаимодействиями, фильтрация данных</a></span><ul class="toc-item"><li><span><a href="#1-комнатные-квартиры" data-toc-modified-id="1-комнатные-квартиры-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>1-комнатные квартиры</a></span><ul class="toc-item"><li><span><a href="#Price-&amp;-Square_Total" data-toc-modified-id="Price-&amp;-Square_Total-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Price &amp; Square_Total</a></span></li></ul></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from os import listdir
import geocoder

# %%
pd.set_option('display.max_rows', 2000)
sns.set(rc={'figure.figsize': (15, 10)})
# %matplotlib inline

# %%
def handle_dataframe(df):
    
    
    def get_coordinate_by_address(Address_List):
        address_set = set(Address_List)
        path = 'C:/Users/qwerty.Oleg/Desktop/MyProject/Data/'
        filename1 = path + 'coord_dict.json'
        filename2 = path + 'coord_not_info_dict.json'

        if 'coord_dict.json' in listdir(path):
            with open(filename1, 'r') as file:
                coord_dict = json.load(file)
        else:
            coord_dict = {}

        if 'coord_not_info_dict.json' in listdir(path):
            with open(filename2, 'r') as file2:
                coord_not_info_dict = json.load(file2)
        else:
            coord_not_info_dict = {}

        len_storage = len(coord_dict)
        print('Coordinates in storage:', len_storage, '\n')

        address_to_load = address_set.difference(set(coord_dict))

        for i, address in enumerate(address_to_load):
            print(i / len(address_to_load))
            g = geocoder.osm(address)
            if g.osm is not None and len(g.osm) == 8:
                coord_dict[address] = g.latlng
            else:
                coord_dict[address] = [None, None]
                coord_not_info_dict[address] = [None, None]

        with open(filename1, 'w') as file1:
            json.dump(coord_dict, file1, ensure_ascii=False)
        with open(filename2, 'w') as file2:
            json.dump(coord_not_info_dict, file2, ensure_ascii=False)

        output_DataFrame = pd.DataFrame(list(map(lambda x: coord_dict[x],Address_List)), 
                              index=Address_List.index, 
                              columns=['X', 'Y'])

        return output_DataFrame


    
    def extract_number_from_squares(x):
        if pd.isna(x):
            return x
        else:
            return float(x.split(' ')[0])
    
    
    def extract_floor(x):
        floor = x.split('/')[0]
        if floor.isdigit():
            return int(floor)
        else:
            return 0
        
                
    columns_order = [#'ид', 
                     'район', 'адрес', 
                     'вид',
                     'год постройки', 'материал', 
                     'этажность', 'этаж', 'тип квартиры', 'цена', 'общая площадь', 
                     'жилая', 'кухня', 'количество комнат', 'отделка', 'санузел', 
                     'балкон/лоджия', 'дата добавления', 'дата истечения']
    
    rename_columns = {#'ид': 'ID', 
                      'район': 'District', 
                      'адрес': 'Address', 
                      'вид': 'Sales_Type', 
                      'год постройки': 'Year_Building', 
                      'материал': 'Material', 
                      'этажность': 'Floors_In_Building', 
                      'этаж': 'Floor', 
                      'тип квартиры': 'Apartment_Type', 
                      'цена': 'Price', 
                      'общая площадь': 'Square_Total', 
                      'жилая': 'Square_Living', 
                      'кухня': 'Square_Kitchen', 
                      'количество комнат': 'Rooms_Number', 
                      'отделка': 'Apartment_Condition', 
                      'санузел': 'Bathroom_Type', 
                      'балкон/лоджия': 'Balcony_Loggia', 
                      'дата добавления': 'Date_Add', 
                      'дата истечения': 'Date_Expiration'}
    
    df[['общая площадь','кухня','жилая']] = df[['общая площадь','кухня','жилая']].applymap(extract_number_from_squares)    
    df['адрес'] = 'Томск, ' + df['адрес']
    df['дата добавления'] = pd.to_datetime(df['дата добавления'], format='%d.%m.%Y %H:%M:%S')
    df['дата истечения'] = pd.to_datetime(df['дата истечения'], format='%d.%m.%Y')
    df['этаж'] = df['этаж/этажность'].map(extract_floor)
    df['год постройки'] = pd.to_numeric(df['год постройки'])
    df['количество комнат'] = pd.to_numeric(df['количество комнат'])
    df['этажность'] = pd.to_numeric(df['этажность'])
    df['цена'] = df['цена'] / 1000
        
    df.drop(['этаж/этажность', 'ид'], axis=1, inplace=True)
    
    df = df[columns_order]
    df = df.rename(columns = rename_columns)
    df['Not_Used'] = 0
    df['Not_Used_Description'] = None
    df = pd.concat([df, get_coordinate_by_address(df['Address'])], axis=1)
    
    
    return df

# %% [markdown]
# Прежде всего следует отбросить квартиры, относящиеся к первичному рынку недвижимости, так как они не должны принимать участие в анализе.

# %%
# df = handle_dataframe(pd.read_json('data.json', orient='index'))
with open('C:/Users/qwerty.Oleg/Desktop/MyProject/Data/data.json', 'r') as fp:
    dict_data = json.load(fp)
    
df = pd.DataFrame.from_dict(dict_data, orient='index')
df = handle_dataframe(df)

df = df[df['Sales_Type'] == 'вторичное']
df
# Out:
# Coordinates in storage: 2040
#                                                              District  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    ленинский район
# ...                                                               ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    ленинский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
#
#                                                                                Address  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  Томск, Ленина (село Тимирязевское)
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 Томск, Мокрушина 13
# https://www.tomsk.ru09.ru/realty?subaction=deta...           Томск, Полины Осипенко 8а
# https://www.tomsk.ru09.ru/realty?subaction=deta...                Томск, Сибирская 118
# https://www.tomsk.ru09.ru/realty?subaction=deta...           Томск, Ференца Мюнниха 22
# ...                                                                                ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...           Томск, Иркутский тракт 17
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  Томск, Береговая 7
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 Томск, Щетинкина 35
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  Томск, Беринга 4/1
# https://www.tomsk.ru09.ru/realty?subaction=deta...              Томск, Ивана Черных 66
#
#                                                    Sales_Type  Year_Building  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное            NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2002.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1963.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2008.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1978.0
# ...                                                       ...            ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1989.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2018.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2011.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1999.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2010.0
#
#                                                    Material  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   дерево
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# ...                                                     ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
#
#                                                     Floors_In_Building  Floor  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   2      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  10      2
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   5      5
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   9      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   9      3
# ...                                                                ...    ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  10      9
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  17      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   3      3
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   6      4
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  19      8
#
#                                                    Apartment_Type   Price  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1490.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  3150.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  3150.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  3280.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  3550.0
# ...                                                           ...     ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  2250.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  2300.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка   900.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  3800.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  2500.0
#
#                                                     Square_Total  ...  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...         60.00  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         57.45  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         43.60  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         67.80  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         64.80  ...
# ...                                                          ...  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         36.00  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         39.00  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         18.00  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         60.00  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...         40.10  ...
#
#                                                     Rooms_Number  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...             2
# https://www.tomsk.ru09.ru/realty?subaction=deta...             2
# https://www.tomsk.ru09.ru/realty?subaction=deta...             2
# https://www.tomsk.ru09.ru/realty?subaction=deta...             2
# https://www.tomsk.ru09.ru/realty?subaction=deta...             3
# ...                                                          ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             2
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
#
#                                                      Apartment_Condition  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# ...                                                                  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
#
#                                                     Bathroom_Type  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...     раздельный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...     раздельный
# ...                                                           ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...     раздельный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
#
#                                                         Balcony_Loggia  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
# ...                                                                ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...              балкон
# https://www.tomsk.ru09.ru/realty?subaction=deta...              балкон
#
#                                                               Date_Add  \
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:03:25
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-04-29 13:36:07
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:04:34
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:06:14
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:07:06
# ...                                                                ...
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-03 20:40:20
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-03 20:36:47
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-04-30 11:57:11
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-04-30 11:57:10
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-04-20 14:21:17
#
#                                                    Date_Expiration Not_Used  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-28        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-06-15        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# ...                                                            ...      ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaT        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaT        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-08-02        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-06-02        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-08-01        0
#
#                                                    Not_Used_Description  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# ...                                                                 ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
#
#                                                             X          Y
# https://www.tomsk.ru09.ru/realty?subaction=deta...        NaN        NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.448548  84.991901
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.457598  84.966826
# https://www.tomsk.ru09.ru/realty?subaction=deta...        NaN        NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.518453  84.986501
# ...                                                       ...        ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.502094  85.007490
# https://www.tomsk.ru09.ru/realty?subaction=deta...        NaN        NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.525391  85.025646
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.512527  85.034669
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.520282  85.051192
#
# [6882 rows x 22 columns]

# %% [markdown]
# # Анализ признаков без взаимодействий, первичная фильтрация
# В данном разделе в целях знакомства с данными будет проведен краткий и поверхностный анализ имеющихся признаков.

# %%
def quantile_values_plot(df, value, groupby=False):
    quantils = []
    values = []
    by = []

    if groupby :
        for j in df[groupby].unique().tolist():
            for i in np.arange(0, 1, 0.01):
                values.append(df.loc[df[groupby] == j, value].quantile(i))
                quantils.append(i)
                by.append('{0}: {1}'.format(groupby, j))
    else:
        for i in np.arange(0, 1, 0.01):
            values.append(df[value].quantile(i))
            quantils.append(i)
        
    plot = sns.lineplot(quantils, values, hue=None if not groupby else by)
    plot.set_xticks(np.arange(0, 1, 0.05))
    plot.set(xlabel='Quantiles', ylabel=value);
    
    return plot

# %%
def count_missing_values(column):
    missing_values = sum(column.isna())
    print('Missing values: {0} ({1}%)'.format(missing_values, 
                                              100 * round(missing_values / len(column), 2)))

# %%
df.columns.tolist()
# Out:
# ['District',
#  'Address',
#  'Sales_Type',
#  'Year_Building',
#  'Material',
#  'Floors_In_Building',
#  'Floor',
#  'Apartment_Type',
#  'Price',
#  'Square_Total',
#  'Square_Living',
#  'Square_Kitchen',
#  'Rooms_Number',
#  'Apartment_Condition',
#  'Bathroom_Type',
#  'Balcony_Loggia',
#  'Date_Add',
#  'Date_Expiration',
#  'Is_Outlier',
#  'Outlier_Description']

# %% [markdown]
# ## Price

# %%
count_missing_values(df['Price'])
df['Price'].describe()
# Out:
# Missing values: 0 (0.0 %)
# count     6746.000000
# mean      3006.237958
# std       2211.148244
# min          8.000000
# 25%       1700.000000
# 50%       2600.000000
# 75%       3600.000000
# max      30000.000000
# Name: Price, dtype: float64

# %% [markdown]
# Из описания признака видно, что наименьшей стоимостью является 300 т.р., медианной 2500 т.р., а наибольшим значением является 42000 т.р. (42 миллиона рублей).
# Следует построить гистрограмму распределения

# %%
plot = sns.distplot(df['Price'])
plot.set_xticks(np.arange(0, 50000,5000));

# %% [markdown]
# Как и предполагалось, ряд имеет ярко выраженную ассиметрию. Эта ситуация весьма типична для рынка недвижимости, так как при большом количестве однородных квартир существует крайне малое количество дорогих квартир.

# %%
plot = quantile_values_plot(df, 'Price')
plot.set_yticks(np.arange(0, 12000,1000));

# %% [markdown]
# Как видно из графика, практически 90% квартир обладают стоимостью менее 5000 т.р.
# В такой ситуации имеет место фильтрация данных, которая будет проводиться в дальнейшем

# %% [markdown]
# ## Square_Total

# %%
count_missing_values(df['Square_Total'])
df['Square_Total'].describe()
# Out:
# Missing values: 0 (0.0 %)
# count    6746.000000
# mean       49.414056
# std        27.324536
# min         8.800000
# 25%        31.000000
# 50%        45.000000
# 75%        63.300000
# max       352.800000
# Name: Square_Total, dtype: float64

# %%
plot = sns.distplot(df['Square_Total'])
plot.set_xticks(np.arange(0, 450,50));

# %%
plot = quantile_values_plot(df, 'Square_Total')
plot.set_yticks(np.arange(0, 140,10));

# %% [markdown]
# Поведение признака Square_Total подобно признаку Price, так как Square_Total сильнее всего влияет на Price.

# %% [markdown]
# ## Square_Kitchen

# %%
count_missing_values(df['Square_Kitchen'])
df['Square_Kitchen'].describe()
# Out:
# Missing values: 4609 (68.0%)
# count    2137.000000
# mean        9.404619
# std         4.008277
# min         1.000000
# 25%         7.000000
# 50%         9.000000
# 75%        11.000000
# max        44.000000
# Name: Square_Kitchen, dtype: float64

# %%
sns.distplot(df['Square_Kitchen']);

# %%
quantile_values_plot(df, 'Square_Kitchen')

# %% [markdown]
# ## Square_Living

# %%
count_missing_values(df['Square_Living'])
df['Square_Living'].describe()
# Out:
# Missing values: 4712 (70.0%)
# count    2034.000000
# mean       34.266323
# std        22.619851
# min         0.000000
# 25%        18.000000
# 50%        30.000000
# 75%        44.000000
# max       450.000000
# Name: Square_Living, dtype: float64

# %%
plot = sns.distplot(df['Square_Living'])
plot.set_xticks(np.arange(0, 450,50));

# %%
plot = quantile_values_plot(df, 'Square_Living')
plot.set_yticks(np.arange(0, 100,5));

# %% [markdown]
# Признаки Square_Kitchen и Square_Living имеют слишком много пропущенных значений, данные признаки следует исключить из анализа.

# %% [markdown]
# ## Floors_In_Building

# %%
count_missing_values(df['Floors_In_Building'])
print(df['Floors_In_Building'].describe())
df['Floors_In_Building'].value_counts()
# Out:
# Missing values: 0 (0.0%)
# count    6746.000000
# mean        8.097391
# std         4.136102
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%        10.000000
# max        21.000000
# Name: Floors_In_Building, dtype: float64
# 5     1874
# 10    1246
# 9     1240
# 17     371
# 6      360
# 2      351
# 3      273
# 14     241
# 4      206
# 18      90
# 12      73
# 7       68
# 16      67
# 15      59
# 11      53
# 8       51
# 19      49
# 1       43
# 21      19
# 13      12
# Name: Floors_In_Building, dtype: int64

# %%
plot = sns.countplot(df['Floors_In_Building'])
plot.set_yticks(np.arange(0, 1901,100));

# %% [markdown]
# Как видно из графика, чаще всего встречаются здания с 5, 9 и 10 этажами, что объясняется большим количеством домов 75 и 86 серий, а также так называемыми "хрущевками".
# <br>
# Эти типы домов зачастую имеют этажность 5, 9 и 10 этажей.

# %% [markdown]
# ## Floor

# %%
count_missing_values(df['Floor'])
print(df['Floor'].describe())
df['Floor'].value_counts()
# Out:
# Missing values: 0 (0.0%)
# count    6746.000000
# mean        4.549659
# std         3.295118
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        21.000000
# Name: Floor, dtype: float64
# 1     1193
# 2     1080
# 5      892
# 3      889
# 4      693
# 6      416
# 7      334
# 8      333
# 9      330
# 10     252
# 11      76
# 12      56
# 13      52
# 14      52
# 16      38
# 15      33
# 17      10
# 19       7
# 18       4
# 0        3
# 21       2
# 20       1
# Name: Floor, dtype: int64

# %%
plot = sns.countplot(df['Floor']);
plot.set_yticks(np.arange(0, 1200,100));

# %% [markdown]
# По графику видно, что с увеличением этажа расположения квартиры, они реже попадают в объявления о продаже.
# <br>
# В дальнейшем предстоит разобраться с природой такого поведения.

# %% [markdown]
# ## District

# %%
count_missing_values(df['District'])
print(df['District'].describe())
df['District'].value_counts()
# Out:
# Missing values: 0 (0.0%)
# count                  6746
# unique                    4
# top       октябрьский район
# freq                   2195
# Name: District, dtype: object
# октябрьский район    2195
# ленинский район      1656
# советский район      1573
# кировский район      1322
# Name: District, dtype: int64

# %%
plot = sns.countplot(df['District'])
plot.set_yticks(np.arange(0, 2300,200));

# %% [markdown]
# Квартиры чаще всего продаются в Октябрьском районе, реже всего в Кировском районе, у Советского и Ленинского примерное равенство.

# %% [markdown]
# ## Year_Building

# %%
count_missing_values(df['Year_Building'])
df['Year_Building'].describe()
# Out:
# Missing values: 892 (13.0%)
# count    5854.000000
# mean     1989.927571
# std        22.142277
# min      1832.000000
# 25%      1974.000000
# 50%      1990.000000
# 75%      2010.000000
# max      2020.000000
# Name: Year_Building, dtype: float64

# %%
plot = sns.distplot(df['Year_Building'])
plot.set_xticks(np.arange(1900, 2021,10));

# %% [markdown]
# На графике видно, что основная часть зданий была построена начиная от 1950 года. Возможно, здания построенные до 1950 года стоит удалить из выборки.

# %% [markdown]
# ## Material

# %%
count_missing_values(df['Material'])
print(df['Material'].describe())
df['Material'].value_counts()
# Out:
# Missing values: 72 (1.0%)
# count       6674
# unique         6
# top       кирпич
# freq        4099
# Name: Material, dtype: object
# кирпич          4099
# панель          2001
# дерево           258
# монолит          223
# шлакоблок         91
# стеноблочный       2
# Name: Material, dtype: int64

# %%
sns.countplot(df['Material']);

# %% [markdown]
# По материалу зданий лидирует кирпич и панель, остальные материалы встречаются крайне редко. Возможно их стоит удалить из выборки.

# %% [markdown]
# ## Apartment_Type

# %%
count_missing_values(df['Apartment_Type'])
print(df['Apartment_Type'].describe())
df['Apartment_Type'].value_counts()
# Out:
# Missing values: 5339 (79.0%)
# count         1407
# unique           6
# top       гостинка
# freq           670
# Name: Apartment_Type, dtype: object
# гостинка          670
# секционка         322
# малогабаритная    288
# комната            99
# двухуровневая      25
# апартаменты         3
# Name: Apartment_Type, dtype: int64

# %%
sns.countplot(df['Apartment_Type']);

# %% [markdown]
# Признак Apartment_Type имеет слишком много пропущенных значений, данный признак не будет принимать участия в дальнейшем анализе.

# %% [markdown]
# ## Rooms_Number

# %%
count_missing_values(df['Rooms_Number'])
print(df['Rooms_Number'].describe())
df['Rooms_Number'].value_counts()
# Out:
# Missing values: 0 (0.0%)
# count    6746.000000
# mean        1.905722
# std         0.923303
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         4.000000
# Name: Rooms_Number, dtype: float64
# 1    2857
# 2    2034
# 3    1489
# 4     366
# Name: Rooms_Number, dtype: int64

# %%
sns.countplot(df['Rooms_Number']);

# %% [markdown]
# Основная доля квартир приходится на квартиры с 1-4 комнатами, все остальные квартиры стоит удалить из выборки.

# %% [markdown]
# ## Apartment_Condition

# %%
count_missing_values(df['Apartment_Condition'])
print(df['Apartment_Condition'].describe())
df['Apartment_Condition'].value_counts()
# Out:
# Missing values: 1116 (17.0%)
# count                    5630
# unique                      4
# top       в хорошем состоянии
# freq                     3098
# Name: Apartment_Condition, dtype: object
# в хорошем состоянии     3098
# в отличном состоянии    1786
# требуется ремонт         491
# черновая отделка         255
# Name: Apartment_Condition, dtype: int64

# %%
sns.countplot(df['Apartment_Condition']);

# %% [markdown]
# Большая часть квартир продается в хорошем состоянии, следом идут квартиры в отличном состоянии.
# В дальнейшем анализе предстоит узнать, как указанное состояние связано с ценой квартиры.

# %% [markdown]
# ## Bathroom_Type

# %%
count_missing_values(df['Bathroom_Type'])
print(df['Bathroom_Type'].describe())
df['Bathroom_Type'].value_counts()
# Out:
# Missing values: 818 (12.0%)
# count            5928
# unique              2
# top       совмещенный
# freq             3040
# Name: Bathroom_Type, dtype: object
# совмещенный    3040
# раздельный     2888
# Name: Bathroom_Type, dtype: int64

# %%
sns.countplot(df['Bathroom_Type']);

# %% [markdown]
# Что касается типа санузла, то чаще всего встречается совмещенный санузел, хотя разница не настолько критична.

# %% [markdown]
# ## Balcony_Loggia

# %%
count_missing_values(df['Balcony_Loggia'])
print(df['Balcony_Loggia'].describe())
df['Balcony_Loggia'].value_counts()
# Out:
# Missing values: 2520 (37.0%)
# count                   4226
# unique                    10
# top       лоджия, остекление
# freq                    1600
# Name: Balcony_Loggia, dtype: object
# лоджия, остекление             1600
# балкон, остекление             1186
# балкон                          734
# 2 лоджии, остекление            229
# лоджия                          199
# балкон и лоджия, остекление     129
# 2 балкона, остекление            80
# 2 балкона                        26
# 2 лоджии                         24
# балкон и лоджия                  19
# Name: Balcony_Loggia, dtype: int64

# %%
plot = sns.countplot(df['Balcony_Loggia'])
plot.set_xticklabels(plot.get_xticklabels(), rotation=20);

# %% [markdown]
# ## Address, Date_Add, Date_Expiration
# Данные признаки не получится проанализировать в том виде, в котором они имеются сейчас, но они будут использованы при попытке создания новых признаков (Feature Engeneering).

# %% [markdown]
# # Анализ признаков с взаимодействиями, фильтрация данных
# В данном разделе будет проведен широкий и детальный анализ данных в разрезе различных признаков и их взаимодействиях.
# Будет проведена обработка данных, фильтрация, заполнение пропусков и т.д.

# %%
df.columns.tolist()
# Out:
# ['District',
#  'Address',
#  'Sales_Type',
#  'Year_Building',
#  'Material',
#  'Floors_In_Building',
#  'Floor',
#  'Apartment_Type',
#  'Price',
#  'Square_Total',
#  'Square_Living',
#  'Square_Kitchen',
#  'Rooms_Number',
#  'Apartment_Condition',
#  'Bathroom_Type',
#  'Balcony_Loggia',
#  'Date_Add',
#  'Date_Expiration',
#  'Is_Outlier',
#  'Outlier_Description']

# %% [markdown]
# На рынке недвижимости ключевым ценообразующим признаком для квартиры считается общая площадь.
# В то же время, отделять одни квартиры от других проще всего используя количество комнат.
# Необходимо выяснить, отличается ли поведение стоимости, например, 1-комнатных квартир от остальных, и так проделать с каждым видом квартир

# %% [markdown]
# Стоит помнить, что ранее было решено удалить из выборки квартиры с количеством комнат более 5 включительно, самое время это сделать

# %%
df = df[df['Rooms_Number'] <= 4]

# %%
quantile_values_plot(df, 'Price', 'Rooms_Number')

# %% [markdown]
# На этом графике отражена зависимость квантилей и соответствующих им стоимостей квартиры в зависимости от количества комнат.
# Из графика следует:
# <li>1 и 2-комнатные квартиры в практически 95% случаев имеют равномерное распределение стоимости, за исключением оставшихся 5%
# <li>3-комнатные квартиры имеют равномерное распределение примерно в 60% случаев, далее идет сильное увеличение стоимости квартир.
# <li>4-комнатные квартиры имеют равномерное распределение примерно в 45% случаев, далее начинается явная ассиметрия в стоимости квартир.

# %%
for i in sorted(df['Rooms_Number'].unique().tolist()):
    sns.kdeplot(df.loc[df['Rooms_Number'] == i, 'Price'], label=i)
plt.legend();

# %%
rooms_count = df['Rooms_Number'].value_counts().tolist()

f, axes = plt.subplots(2, 2)

sns.regplot(x='Square_Total', y='Price', data=df[df['Rooms_Number'] == 1], ax=axes[0, 0])
sns.regplot(x='Square_Total', y='Price', data=df[df['Rooms_Number'] == 2], ax=axes[0, 1])
sns.regplot(x='Square_Total', y='Price', data=df[df['Rooms_Number'] == 3], ax=axes[1, 0])
sns.regplot(x='Square_Total', y='Price', data=df[df['Rooms_Number'] == 4], ax=axes[1, 1])
axes[0, 0].legend(["Room 1 (Sample:{0})".format(rooms_count[0])])
axes[0, 1].legend(["Room 2 (Sample:{0})".format(rooms_count[1])])
axes[1, 0].legend(["Room 3 (Sample:{0})".format(rooms_count[2])])
axes[1, 1].legend(["Room 4 (Sample:{0})".format(rooms_count[3])]);

# %% [markdown]
# На всех графиках видно, что природа стоимости квартиры сильно меняется в зависимости от количества квартир.
# Дальнейший анализ будет проводится отдельно для каждого вида квартир.

# %% [markdown]
# ## 1-комнатные квартиры

# %%
df_room_1 = df[df['Rooms_Number'] == 1]
df_room_1.head(5)
# Out:
#                                                              District  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
#
#                                                                       Address  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...      Томск, Архитекторов 9
# https://www.tomsk.ru09.ru/realty?subaction=deta...         Томск, Тверская 68
# https://www.tomsk.ru09.ru/realty?subaction=deta...           Томск, Кулева 32
# https://www.tomsk.ru09.ru/realty?subaction=deta...  Томск, Максима Горького 9
# https://www.tomsk.ru09.ru/realty?subaction=deta...    Томск, Белинского 21а/1
#
#                                                    Sales_Type  Year_Building  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2014.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1973.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1951.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1963.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1956.0
#
#                                                    Material  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   дерево
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
#
#                                                     Floors_In_Building  Floor  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  10      9
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   5      3
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   4      4
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   2      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   3      1
#
#                                                    Apartment_Type   Price  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1950.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка  1100.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...        комната   960.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1350.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка  1000.0
#
#                                                     Square_Total  ...  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...          32.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          13.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          16.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          33.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          24.0  ...
#
#                                                     Rooms_Number  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
#
#                                                     Apartment_Condition  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  NaN
#
#                                                     Bathroom_Type  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...     раздельный
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
#
#                                                         Balcony_Loggia  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
#
#                                                               Date_Add  \
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:07:30
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:02:32
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:06:18
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:06:13
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:03:04
#
#                                                    Date_Expiration Not_Used  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-06-15        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-06-15        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
#
#                                                    Not_Used_Description  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
#
#                                                             X          Y
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.495478  85.055889
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.474955  84.971375
# https://www.tomsk.ru09.ru/realty?subaction=deta...        NaN        NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.479571  84.942148
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.470478  84.957613
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Price & Square_Total

# %%
plot = sns.distplot(df_room_1['Price'])
plot.set_xticks(np.arange(0, 7000,500));

# %%
plot = sns.distplot(df_room_1['Square_Total'])
plot.set_xticks(np.arange(0, 81,5));

# %%
plot = quantile_values_plot(df_room_1, 'Price')
plot.set_yticks(np.arange(0, 4001, 500));

# %%
plot = quantile_values_plot(df_room_1, 'Square_Total')
plot.set_yticks(np.arange(0,51, 5));

# %%
sns.regplot(x='Square_Total', y='Price', data=df_room_1);

# %%
df_room_1['Price'].quantile(.05)
# Out:
# 589.0

# %%
df_room_1['Price'].quantile(.9)
# Out:
# 2750.0

# %%
from importlib import reload
from constants import *

# %%
reload(constants)
# Out:
# <module 'constants' from 'C:\\Users\\qwerty.Oleg\\Desktop\\MyProject\\Exploratory-Data-Analysis\\constants.py'>

# %%
def filter_data(data):
    
    df = data.copy()
    filter_1 = 'PRICE_UPPER_BOUND_ROOMS_1'
    price_higher_bound = [i > PRICE_UPPER_BOUND_ROOMS_1 for i in df['Price']]
    df.loc[price_higher_bound, 'Not_Used'] = 1
    df.loc[price_higher_bound, 'Not_Used_Description'] = [filter_1 if i is None and filter_1 not in i else  i + ', {0}'.format(filter_1) for i in df.loc[price_higher_bound, 'Not_Used_Description']]
    
    filter_2 = 'PRICE_LOWER_BOUND_ROOMS_1'
    price_lower_bound = [i < PRICE_LOWER_BOUND_ROOMS_1 for i in df['Price']]
    df.loc[price_lower_bound, 'Not_Used'] = 1
    df.loc[price_lower_bound, 'Not_Used_Description'] = [filter_2 if i is None and filter_2 not in i else  i + ', {0}'.format(filter_2) for i in df.loc[price_lower_bound, 'Not_Used_Description']]
    
    return df

# %%
PRICE_LOWER_BOUND_ROOMS_1.__format__
# Out:
# <function int.__format__(format_spec, /)>

# %%
filter_1 = 'PRICE_UPPER_BOUND_ROOMS_1'
price_higher_bound = [i > PRICE_UPPER_BOUND_ROOMS_1 for i in df_room_1['Price']]
df_room_1.loc[price_higher_bound, 'Not_Used'] = 1
# Out:
# C:\Users\qwerty.Oleg\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
def check_prices_bound(column, lower_bound, upper_bound):
    lower = 'PRICE_LOWER_BOUND'
    higher = 'PRICE_HIGHER_BOUND'
    
    price_higher_bound = [i > upper_bound for i in column]
    df.loc[price_higher_bound, 'Not_Used'] = 1
    
    return price_higher_bound

# %%
PRICE_UPPER_BOUND_ROOMS_1
# Out:
# 1500

# %%
check_prices_bound(lower_bound=PRICE_LOWER_BOUND_ROOMS_1, upper_bound=PRICE_UPPER_BOUND_ROOMS_1)
# Out:
# {'lower_bound': 500, 'upper_bound': 1500}

# %%
df_room_1
# Out:
#                                                              District  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# ...                                                               ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...    советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    ленинский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
#
#                                                                       Address  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...      Томск, Архитекторов 9
# https://www.tomsk.ru09.ru/realty?subaction=deta...         Томск, Тверская 68
# https://www.tomsk.ru09.ru/realty?subaction=deta...           Томск, Кулева 32
# https://www.tomsk.ru09.ru/realty?subaction=deta...  Томск, Максима Горького 9
# https://www.tomsk.ru09.ru/realty?subaction=deta...    Томск, Белинского 21а/1
# ...                                                                       ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  Томск, Нижний переулок 47
# https://www.tomsk.ru09.ru/realty?subaction=deta...  Томск, Иркутский тракт 17
# https://www.tomsk.ru09.ru/realty?subaction=deta...         Томск, Береговая 7
# https://www.tomsk.ru09.ru/realty?subaction=deta...        Томск, Щетинкина 35
# https://www.tomsk.ru09.ru/realty?subaction=deta...     Томск, Ивана Черных 66
#
#                                                    Sales_Type  Year_Building  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2014.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1973.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1951.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1963.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1956.0
# ...                                                       ...            ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2017.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1989.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2018.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2011.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2010.0
#
#                                                    Material  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   дерево
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# ...                                                     ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
#
#                                                     Floors_In_Building  Floor  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  10      9
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   5      3
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   4      4
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   2      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   3      1
# ...                                                                ...    ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  14     14
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  10      9
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  17      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   3      3
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  19      8
#
#                                                    Apartment_Type   Price  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1950.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка  1100.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...        комната   960.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1350.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка  1000.0
# ...                                                           ...     ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1700.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  2250.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  2300.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка   900.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  2500.0
#
#                                                     Square_Total  ...  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...          32.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          13.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          16.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          33.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          24.0  ...
# ...                                                          ...  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          41.2  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          36.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          39.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          18.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          40.1  ...
#
#                                                     Rooms_Number  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# ...                                                          ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
#
#                                                      Apartment_Condition  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# ...                                                                  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...      черновая отделка
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
#
#                                                     Bathroom_Type  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...     раздельный
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# ...                                                           ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
#
#                                                         Balcony_Loggia  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# ...                                                                ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...              лоджия
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...              балкон
#
#                                                               Date_Add  \
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:07:30
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:02:32
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:06:18
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:06:13
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:03:04
# ...                                                                ...
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-03 20:40:59
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-03 20:40:20
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-03 20:36:47
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-04-30 11:57:11
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-04-20 14:21:17
#
#                                                    Date_Expiration Not_Used  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        1
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-06-15        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-06-15        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# ...                                                            ...      ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-08-01        1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaT        1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaT        1
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-08-02        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-08-01        1
#
#                                                    Not_Used_Description  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# ...                                                                 ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 None
#
#                                                             X          Y
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.495478  85.055889
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.474955  84.971375
# https://www.tomsk.ru09.ru/realty?subaction=deta...        NaN        NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.479571  84.942148
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.470478  84.957613
# ...                                                       ...        ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.484809  85.020961
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.502094  85.007490
# https://www.tomsk.ru09.ru/realty?subaction=deta...        NaN        NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.525391  85.025646
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.520282  85.051192
#
# [2904 rows x 22 columns]

# %%
test = df_room_1[0:10].copy()

# %%
price_higher_bound = [i > PRICE_UPPER_BOUND_ROOMS_1 for i in test['Price']]

# %%
price_higher_bound
# Out:
# [False, False, False, False, False, False, False, True, False, True]

# %%
test.loc[not_used_idx_price, ['Not_Used', 'Not_Used_Description']] = 1, ['PRICE_UPPER_BOUND_ROOMS_1' if i is None else  i + ', qwe' for i in test.loc[not_used_idx_price, 'Not_Used_Description']]

# %%
['PRICE_UPPER_BOUND_ROOMS_1' if i is None else  i + ', qwe' for i in test.loc[not_used_idx_price, 'Not_Used_Description']]
# Out:
# ['PRICE_UPPER_BOUND_ROOMS_1, qwe, qwe', 'PRICE_UPPER_BOUND_ROOMS_1, qwe, qwe']

# %%
test
# Out:
#                                                              District  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  октябрьский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    ленинский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...    кировский район
#
#                                                                                       Address  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                      Томск, Архитекторов 9
# https://www.tomsk.ru09.ru/realty?subaction=deta...                         Томск, Тверская 68
# https://www.tomsk.ru09.ru/realty?subaction=deta...                           Томск, Кулева 32
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  Томск, Максима Горького 9
# https://www.tomsk.ru09.ru/realty?subaction=deta...                    Томск, Белинского 21а/1
# https://www.tomsk.ru09.ru/realty?subaction=deta...  Томск, Усова 21/3 (Красноармейская 120/1)
# https://www.tomsk.ru09.ru/realty?subaction=deta...     Томск, Богдана Хмельницкого переулок 8
# https://www.tomsk.ru09.ru/realty?subaction=deta...               Томск, Иркутский тракт 185/1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                       Томск, Батистовая 16
# https://www.tomsk.ru09.ru/realty?subaction=deta...   Томск, Богдана Хмельницкого переулок 5/1
#
#                                                    Sales_Type  Year_Building  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2014.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1973.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1951.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1963.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1956.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         1979.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2010.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2013.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное         2013.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...  вторичное            NaN
#
#                                                    Material  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   дерево
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич
#
#                                                     Floors_In_Building  Floor  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  10      9
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   5      3
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   4      4
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   2      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   3      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   9      6
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  12      9
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  14     14
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   3      1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                  16      6
#
#                                                    Apartment_Type   Price  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1950.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка  1100.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...        комната   960.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1350.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка  1000.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      секционка   900.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  1720.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  2100.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...       гостинка  1100.0
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN  2250.0
#
#                                                     Square_Total  ...  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...          32.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          13.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          16.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          33.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          24.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          17.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          30.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          36.6  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          16.0  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...          37.0  ...
#
#                                                     Rooms_Number  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
# https://www.tomsk.ru09.ru/realty?subaction=deta...             1
#
#                                                      Apartment_Condition  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
#
#                                                     Bathroom_Type  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...     раздельный
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...    совмещенный
# https://www.tomsk.ru09.ru/realty?subaction=deta...     раздельный
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...            NaN
#
#                                                         Balcony_Loggia  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
#
#                                                               Date_Add  \
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:07:30
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:02:32
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:06:18
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:06:13
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:03:04
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:02:41
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:02:57
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-04-27 10:04:51
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-05-01 13:08:26
# https://www.tomsk.ru09.ru/realty?subaction=deta... 2020-04-28 22:19:58
#
#                                                    Date_Expiration Not_Used  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-06-15        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-06-15        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-26        1
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-30        0
# https://www.tomsk.ru09.ru/realty?subaction=deta...      2020-07-27        1
#
#                                                                         Not_Used_Description  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                                      None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                                      None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                                      None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                                      None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                                      None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                                      None
# https://www.tomsk.ru09.ru/realty?subaction=deta...                                      None
# https://www.tomsk.ru09.ru/realty?subaction=deta...  PRICE_UPPER_BOUND_ROOMS_1, qwe, qwe, qwe
# https://www.tomsk.ru09.ru/realty?subaction=deta...                                      None
# https://www.tomsk.ru09.ru/realty?subaction=deta...  PRICE_UPPER_BOUND_ROOMS_1, qwe, qwe, qwe
#
#                                                             X          Y
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.495478  85.055889
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.474955  84.971375
# https://www.tomsk.ru09.ru/realty?subaction=deta...        NaN        NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.479571  84.942148
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.470478  84.957613
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.463456  84.970861
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.454762  85.020852
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.519952  85.073601
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.528328  84.973739
# https://www.tomsk.ru09.ru/realty?subaction=deta...  56.455284  85.020215
#
# [10 rows x 22 columns]
